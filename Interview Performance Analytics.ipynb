# %%
## Importing Necessary Libraries

import pandas as pd
import yt_dlp
import os
from pydub import AudioSegment
from moviepy.editor import VideoFileClip
import speech_recognition as sr
import time
import os
import speech_recognition as sr
from pydub import AudioSegment
from tqdm import tqdm

# %% [markdown]
# ## Load CSV data Extract their audio (.wav)

# %%
# Load the CSV file (assuming it's in the same directory as the script)
file_path = 'D:\excel.csv'  # Ensure this matches your file name
print("Loading CSV file...")
excel_data = pd.read_csv(file_path)
urls = excel_data['UPSC Interview Video Link']

# Print the URLs to verify they are loaded correctly
print("URLs loaded from file:")
print(urls)

# Directory to save audio files
output_dir = r'output_audio_files'
os.makedirs(output_dir, exist_ok=True)
print(f"Audio directory created at: {output_dir}")

# Function to download audio in the best available format and convert to WAV
def download_and_convert_to_wav(url, output_name):
    try:
        print(f"Attempting to download audio from: {url}")
        ydl_opts = {
            'format': 'bestaudio/best',     # Download the best audio quality available
            'outtmpl': output_name + ".%(ext)s",  # Save with original extension
            'noplaylist': True              # Download only the single video
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(url, download=True)
            downloaded_file = ydl.prepare_filename(info_dict)  # Get the downloaded file name

        # Convert to WAV using FFmpeg via Pydub
        wav_path = f"{output_name}.wav"
        audio = AudioSegment.from_file(downloaded_file)  # Read the downloaded file
        audio.export(wav_path, format="wav")             # Convert to WAV
        print(f"Converted and saved as WAV: {wav_path}")

        # Clean up original downloaded file
        os.remove(downloaded_file)

    except Exception as e:
        print(f"Failed to download or convert {url}: {e}")

# Loop through each URL and download audio as WAV
for i, url in enumerate(urls):
    output_name = os.path.join(output_dir, f"audio_{i+1}")
    download_and_convert_to_wav(url, output_name)

print("Script completed.")
# Out:
# Loading CSV file...
# URLs loaded from file:
# 0     https://www.youtube.com/watch?v=vQ_2x-lXaOY&li...
# 1     https://www.youtube.com/watch?v=ER13v7aSzN0&li...
# 2     https://www.youtube.com/watch?v=Z-j-mXXLIRk&li...
# 3     https://www.youtube.com/watch?v=FI8MKQ2RMiU&li...
# 4     https://www.youtube.com/watch?v=HdcfyH93TQE&li...
# 5     https://www.youtube.com/watch?v=T_RJUJXOdp8&li...
# 6     https://www.youtube.com/watch?v=cwIbUnSs4gc&li...
# 7     https://www.youtube.com/watch?v=QisNg2U_0Mw&li...
# 8     https://www.youtube.com/watch?v=3SO0A-W_SqM&li...
# 9     https://www.youtube.com/watch?v=8IDiAEIBqTE&li...
# 10    https://www.youtube.com/watch?v=NOOrUcAb-Fo&li...
# 11    https://www.youtube.com/watch?v=0Z-s8qo6hXg&li...
# 12    https://www.youtube.com/watch?v=UzXlVHtfXBQ&li...
# 13    https://www.youtube.com/watch?v=Drnob9EN0jg&li...
# 14    https://www.youtube.com/watch?v=d-WQraw9e94&li...
# 15    https://www.youtube.com/watch?v=-jbNtPc7NOw&li...
# 16    https://www.youtube.com/watch?v=LTYWLwmAfdk&li...
# 17    https://www.youtube.com/watch?v=wlAA6xgDQ1k&li...
# 18    https://www.youtube.com/watch?v=kzHx6HOAOAo&li...
# 19    https://www.youtube.com/watch?v=goSff582sE8&li...
# 20    https://www.youtube.com/watch?v=IGh4T57q6C4&li...
# 21    https://www.youtube.com/watch?v=-DM-CTxU11s&li...
# 22    https://www.youtube.com/watch?v=7x_sONV6BBU&li...
# 23    https://www.youtube.com/watch?v=jgaCBxTj-A4&li...
# 24    https://www.youtube.com/watch?v=mhRVI-yT7Q8&li...
# 25    https://www.youtube.com/watch?v=X8aoNCA5kyM&li...
# 26    https://www.youtube.com/watch?v=zX4hfPn-ls4&li...
# 27    https://www.youtube.com/watch?v=KnE6NPtjx3s&li...
# 28    https://www.youtube.com/watch?v=L8Dj1v5QV_s&li...
# 29    https://www.youtube.com/watch?v=J6FDpdhW0ns&li...
# Name: UPSC Interview Video Link, dtype: object
# Audio directory created at: output_audio_files
# Attempting to download audio from: https://www.youtube.com/watch?v=vQ_2x-lXaOY&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=vQ_2x-lXaOY&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ
# [youtube:tab] Downloading just the video vQ_2x-lXaOY because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vQ_2x-lXaOY
# [youtube] vQ_2x-lXaOY: Downloading webpage
# [youtube] vQ_2x-lXaOY: Downloading ios player API JSON
# [youtube] vQ_2x-lXaOY: Downloading mweb player API JSON
# [youtube] vQ_2x-lXaOY: Downloading player bdd97f2d
# [youtube] vQ_2x-lXaOY: Downloading m3u8 information
# [info] vQ_2x-lXaOY: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_1.webm
# [download] 100% of   28.53MiB in 00:00:17 at 1.59MiB/s
# Converted and saved as WAV: output_audio_files\audio_1.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=ER13v7aSzN0&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=2
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=ER13v7aSzN0&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=2
# [youtube:tab] Downloading just the video ER13v7aSzN0 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ER13v7aSzN0
# [youtube] ER13v7aSzN0: Downloading webpage
# [youtube] ER13v7aSzN0: Downloading ios player API JSON
# [youtube] ER13v7aSzN0: Downloading mweb player API JSON
# [youtube] ER13v7aSzN0: Downloading m3u8 information
# [info] ER13v7aSzN0: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_2.webm
# [download] 100% of   27.39MiB in 00:00:26 at 1.03MiB/s
# Converted and saved as WAV: output_audio_files\audio_2.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=Z-j-mXXLIRk&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=3
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=Z-j-mXXLIRk&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=3
# [youtube:tab] Downloading just the video Z-j-mXXLIRk because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Z-j-mXXLIRk
# [youtube] Z-j-mXXLIRk: Downloading webpage
# [youtube] Z-j-mXXLIRk: Downloading ios player API JSON
# [youtube] Z-j-mXXLIRk: Downloading mweb player API JSON
# [youtube] Z-j-mXXLIRk: Downloading m3u8 information
# [info] Z-j-mXXLIRk: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_3.webm
# [download] 100% of   27.74MiB in 00:00:21 at 1.27MiB/s
# Converted and saved as WAV: output_audio_files\audio_3.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=FI8MKQ2RMiU&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=4
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=FI8MKQ2RMiU&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=4
# [youtube:tab] Downloading just the video FI8MKQ2RMiU because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FI8MKQ2RMiU
# [youtube] FI8MKQ2RMiU: Downloading webpage
# [youtube] FI8MKQ2RMiU: Downloading ios player API JSON
# [youtube] FI8MKQ2RMiU: Downloading mweb player API JSON
# [youtube] FI8MKQ2RMiU: Downloading m3u8 information
# [info] FI8MKQ2RMiU: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_4.webm
# [download] 100% of   27.20MiB in 00:00:29 at 937.86KiB/s
# Converted and saved as WAV: output_audio_files\audio_4.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=HdcfyH93TQE&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=5
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=HdcfyH93TQE&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=5
# [youtube:tab] Downloading just the video HdcfyH93TQE because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HdcfyH93TQE
# [youtube] HdcfyH93TQE: Downloading webpage
# [youtube] HdcfyH93TQE: Downloading ios player API JSON
# [youtube] HdcfyH93TQE: Downloading mweb player API JSON
# [youtube] HdcfyH93TQE: Downloading m3u8 information
# [info] HdcfyH93TQE: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_5.webm
# [download] 100% of   37.51MiB in 00:00:37 at 1021.82KiB/s
# Converted and saved as WAV: output_audio_files\audio_5.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=T_RJUJXOdp8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=6
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=T_RJUJXOdp8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=6
# [youtube:tab] Downloading just the video T_RJUJXOdp8 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T_RJUJXOdp8
# [youtube] T_RJUJXOdp8: Downloading webpage
# [youtube] T_RJUJXOdp8: Downloading ios player API JSON
# [youtube] T_RJUJXOdp8: Downloading mweb player API JSON
# [youtube] T_RJUJXOdp8: Downloading m3u8 information
# [info] T_RJUJXOdp8: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_6.webm
# [download] 100% of   30.11MiB in 00:00:34 at 897.24KiB/s
# Converted and saved as WAV: output_audio_files\audio_6.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=cwIbUnSs4gc&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=7
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=cwIbUnSs4gc&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=7
# [youtube:tab] Downloading just the video cwIbUnSs4gc because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cwIbUnSs4gc
# [youtube] cwIbUnSs4gc: Downloading webpage
# [youtube] cwIbUnSs4gc: Downloading ios player API JSON
# [youtube] cwIbUnSs4gc: Downloading mweb player API JSON
# [youtube] cwIbUnSs4gc: Downloading m3u8 information
# [info] cwIbUnSs4gc: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_7.webm
# [download] 100% of   30.08MiB in 00:00:27 at 1.09MiB/s
# Converted and saved as WAV: output_audio_files\audio_7.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=QisNg2U_0Mw&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=8
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=QisNg2U_0Mw&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=8
# [youtube:tab] Downloading just the video QisNg2U_0Mw because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QisNg2U_0Mw
# [youtube] QisNg2U_0Mw: Downloading webpage
# [youtube] QisNg2U_0Mw: Downloading ios player API JSON
# [youtube] QisNg2U_0Mw: Downloading mweb player API JSON
# [youtube] QisNg2U_0Mw: Downloading m3u8 information
# [info] QisNg2U_0Mw: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_8.webm
# [download] 100% of   38.50MiB in 00:00:26 at 1.46MiB/s
# Converted and saved as WAV: output_audio_files\audio_8.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=3SO0A-W_SqM&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=9
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=3SO0A-W_SqM&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=9
# [youtube:tab] Downloading just the video 3SO0A-W_SqM because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3SO0A-W_SqM
# [youtube] 3SO0A-W_SqM: Downloading webpage
# [youtube] 3SO0A-W_SqM: Downloading ios player API JSON
# [youtube] 3SO0A-W_SqM: Downloading mweb player API JSON
# [youtube] 3SO0A-W_SqM: Downloading m3u8 information
# [info] 3SO0A-W_SqM: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_9.webm
# [download] 100% of   32.87MiB in 00:00:46 at 721.65KiB/s
# Converted and saved as WAV: output_audio_files\audio_9.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=8IDiAEIBqTE&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=10
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=8IDiAEIBqTE&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=10
# [youtube:tab] Downloading just the video 8IDiAEIBqTE because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8IDiAEIBqTE
# [youtube] 8IDiAEIBqTE: Downloading webpage
# [youtube] 8IDiAEIBqTE: Downloading ios player API JSON
# [youtube] 8IDiAEIBqTE: Downloading mweb player API JSON
# [youtube] 8IDiAEIBqTE: Downloading m3u8 information
# [info] 8IDiAEIBqTE: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_10.webm
# [download] 100% of   25.67MiB in 00:00:13 at 1.97MiB/s
# Converted and saved as WAV: output_audio_files\audio_10.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=NOOrUcAb-Fo&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=12
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=NOOrUcAb-Fo&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=12
# [youtube:tab] Downloading just the video NOOrUcAb-Fo because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NOOrUcAb-Fo
# [youtube] NOOrUcAb-Fo: Downloading webpage
# [youtube] NOOrUcAb-Fo: Downloading ios player API JSON
# [youtube] NOOrUcAb-Fo: Downloading mweb player API JSON
# [youtube] NOOrUcAb-Fo: Downloading m3u8 information
# [info] NOOrUcAb-Fo: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_11.webm
# [download] 100% of   30.70MiB in 00:00:28 at 1.09MiB/s
# Converted and saved as WAV: output_audio_files\audio_11.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=0Z-s8qo6hXg&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=15
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=0Z-s8qo6hXg&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=15
# [youtube:tab] Downloading just the video 0Z-s8qo6hXg because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0Z-s8qo6hXg
# [youtube] 0Z-s8qo6hXg: Downloading webpage
# [youtube] 0Z-s8qo6hXg: Downloading ios player API JSON
# [youtube] 0Z-s8qo6hXg: Downloading mweb player API JSON
# [youtube] 0Z-s8qo6hXg: Downloading m3u8 information
# [info] 0Z-s8qo6hXg: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_12.webm
# [download] 100% of   31.98MiB in 00:00:16 at 1.88MiB/s
# Converted and saved as WAV: output_audio_files\audio_12.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=UzXlVHtfXBQ&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=16
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=UzXlVHtfXBQ&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=16
# [youtube:tab] Downloading just the video UzXlVHtfXBQ because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UzXlVHtfXBQ
# [youtube] UzXlVHtfXBQ: Downloading webpage
# [youtube] UzXlVHtfXBQ: Downloading ios player API JSON
# [youtube] UzXlVHtfXBQ: Downloading mweb player API JSON
# [youtube] UzXlVHtfXBQ: Downloading player 2d24ba15
# [youtube] UzXlVHtfXBQ: Downloading m3u8 information
# [info] UzXlVHtfXBQ: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_13.webm
# [download] 100% of   39.21MiB in 00:00:15 at 2.57MiB/s
# Converted and saved as WAV: output_audio_files\audio_13.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=Drnob9EN0jg&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=18
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=Drnob9EN0jg&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=18
# [youtube:tab] Downloading just the video Drnob9EN0jg because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Drnob9EN0jg
# [youtube] Drnob9EN0jg: Downloading webpage
# [youtube] Drnob9EN0jg: Downloading ios player API JSON
# [youtube] Drnob9EN0jg: Downloading mweb player API JSON
# [youtube] Drnob9EN0jg: Downloading m3u8 information
# [info] Drnob9EN0jg: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_14.webm
# [download] 100% of   37.13MiB in 00:00:14 at 2.55MiB/s
# Converted and saved as WAV: output_audio_files\audio_14.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=d-WQraw9e94&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=19
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=d-WQraw9e94&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=19
# [youtube:tab] Downloading just the video d-WQraw9e94 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=d-WQraw9e94
# [youtube] d-WQraw9e94: Downloading webpage
# [youtube] d-WQraw9e94: Downloading ios player API JSON
# [youtube] d-WQraw9e94: Downloading mweb player API JSON
# [youtube] d-WQraw9e94: Downloading m3u8 information
# [info] d-WQraw9e94: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_15.webm
# [download] 100% of   28.18MiB in 00:00:08 at 3.22MiB/s
# Converted and saved as WAV: output_audio_files\audio_15.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=-jbNtPc7NOw&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=22
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=-jbNtPc7NOw&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=22
# [youtube:tab] Downloading just the video -jbNtPc7NOw because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-jbNtPc7NOw
# [youtube] -jbNtPc7NOw: Downloading webpage
# [youtube] -jbNtPc7NOw: Downloading ios player API JSON
# [youtube] -jbNtPc7NOw: Downloading mweb player API JSON
# [youtube] -jbNtPc7NOw: Downloading m3u8 information
# [info] -jbNtPc7NOw: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_16.webm
# [download] 100% of   36.47MiB in 00:00:11 at 3.20MiB/s
# Converted and saved as WAV: output_audio_files\audio_16.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=LTYWLwmAfdk&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=23
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=LTYWLwmAfdk&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=23
# [youtube:tab] Downloading just the video LTYWLwmAfdk because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LTYWLwmAfdk
# [youtube] LTYWLwmAfdk: Downloading webpage
# [youtube] LTYWLwmAfdk: Downloading ios player API JSON
# [youtube] LTYWLwmAfdk: Downloading mweb player API JSON
# [youtube] LTYWLwmAfdk: Downloading m3u8 information
# [info] LTYWLwmAfdk: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_17.webm
# [download] 100% of   28.49MiB in 00:00:08 at 3.18MiB/s
# Converted and saved as WAV: output_audio_files\audio_17.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=wlAA6xgDQ1k&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=24
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=wlAA6xgDQ1k&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=24
# [youtube:tab] Downloading just the video wlAA6xgDQ1k because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wlAA6xgDQ1k
# [youtube] wlAA6xgDQ1k: Downloading webpage
# [youtube] wlAA6xgDQ1k: Downloading ios player API JSON
# [youtube] wlAA6xgDQ1k: Downloading mweb player API JSON
# [youtube] wlAA6xgDQ1k: Downloading m3u8 information
# [info] wlAA6xgDQ1k: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_18.webm
# [download] 100% of   31.28MiB in 00:00:12 at 2.57MiB/s
# Converted and saved as WAV: output_audio_files\audio_18.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=kzHx6HOAOAo&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=25
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=kzHx6HOAOAo&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=25
# [youtube:tab] Downloading just the video kzHx6HOAOAo because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kzHx6HOAOAo
# [youtube] kzHx6HOAOAo: Downloading webpage
# [youtube] kzHx6HOAOAo: Downloading ios player API JSON
# [youtube] kzHx6HOAOAo: Downloading mweb player API JSON
# [youtube] kzHx6HOAOAo: Downloading m3u8 information
# [info] kzHx6HOAOAo: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_19.webm
# [download] 100% of   30.87MiB in 00:00:13 at 2.34MiB/s
# Converted and saved as WAV: output_audio_files\audio_19.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=goSff582sE8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=27
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=goSff582sE8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=27
# [youtube:tab] Downloading just the video goSff582sE8 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=goSff582sE8
# [youtube] goSff582sE8: Downloading webpage
# [youtube] goSff582sE8: Downloading ios player API JSON
# [youtube] goSff582sE8: Downloading mweb player API JSON
# [youtube] goSff582sE8: Downloading m3u8 information
# [info] goSff582sE8: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_20.webm
# [download] 100% of   29.10MiB in 00:00:17 at 1.67MiB/s
# Converted and saved as WAV: output_audio_files\audio_20.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=IGh4T57q6C4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=28
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=IGh4T57q6C4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=28
# [youtube:tab] Downloading just the video IGh4T57q6C4 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IGh4T57q6C4
# [youtube] IGh4T57q6C4: Downloading webpage
# [youtube] IGh4T57q6C4: Downloading ios player API JSON
# [youtube] IGh4T57q6C4: Downloading mweb player API JSON
# [youtube] IGh4T57q6C4: Downloading m3u8 information
# [info] IGh4T57q6C4: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_21.webm
# [download] 100% of   33.86MiB in 00:00:18 at 1.82MiB/s
# Converted and saved as WAV: output_audio_files\audio_21.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=-DM-CTxU11s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=29
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=-DM-CTxU11s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=29
# [youtube:tab] Downloading just the video -DM-CTxU11s because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-DM-CTxU11s
# [youtube] -DM-CTxU11s: Downloading webpage
# [youtube] -DM-CTxU11s: Downloading ios player API JSON
# [youtube] -DM-CTxU11s: Downloading mweb player API JSON
# [youtube] -DM-CTxU11s: Downloading m3u8 information
# [info] -DM-CTxU11s: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_22.webm
# [download] 100% of   34.18MiB in 00:00:21 at 1.56MiB/s
# Converted and saved as WAV: output_audio_files\audio_22.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=7x_sONV6BBU&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=30
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=7x_sONV6BBU&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=30
# [youtube:tab] Downloading just the video 7x_sONV6BBU because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7x_sONV6BBU
# [youtube] 7x_sONV6BBU: Downloading webpage
# [youtube] 7x_sONV6BBU: Downloading ios player API JSON
# [youtube] 7x_sONV6BBU: Downloading mweb player API JSON
# [youtube] 7x_sONV6BBU: Downloading m3u8 information
# [info] 7x_sONV6BBU: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_23.webm
# [download] 100% of   28.53MiB in 00:00:16 at 1.71MiB/s
# Converted and saved as WAV: output_audio_files\audio_23.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=jgaCBxTj-A4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=31
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=jgaCBxTj-A4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=31
# [youtube:tab] Downloading just the video jgaCBxTj-A4 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jgaCBxTj-A4
# [youtube] jgaCBxTj-A4: Downloading webpage
# [youtube] jgaCBxTj-A4: Downloading ios player API JSON
# [youtube] jgaCBxTj-A4: Downloading mweb player API JSON
# [youtube] jgaCBxTj-A4: Downloading m3u8 information
# [info] jgaCBxTj-A4: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_24.webm
# [download] 100% of   29.82MiB in 00:00:13 at 2.16MiB/s
# Converted and saved as WAV: output_audio_files\audio_24.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=mhRVI-yT7Q8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=32
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=mhRVI-yT7Q8&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=32
# [youtube:tab] Downloading just the video mhRVI-yT7Q8 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mhRVI-yT7Q8
# [youtube] mhRVI-yT7Q8: Downloading webpage
# [youtube] mhRVI-yT7Q8: Downloading ios player API JSON
# [youtube] mhRVI-yT7Q8: Downloading mweb player API JSON
# [youtube] mhRVI-yT7Q8: Downloading m3u8 information
# [info] mhRVI-yT7Q8: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_25.webm
# [download] 100% of   27.12MiB in 00:00:18 at 1.43MiB/s
# Converted and saved as WAV: output_audio_files\audio_25.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=X8aoNCA5kyM&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=33
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=X8aoNCA5kyM&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=33
# [youtube:tab] Downloading just the video X8aoNCA5kyM because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X8aoNCA5kyM
# [youtube] X8aoNCA5kyM: Downloading webpage
# [youtube] X8aoNCA5kyM: Downloading ios player API JSON
# [youtube] X8aoNCA5kyM: Downloading mweb player API JSON
# [youtube] X8aoNCA5kyM: Downloading m3u8 information
# [info] X8aoNCA5kyM: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_26.webm
# [download] 100% of   28.67MiB in 00:00:12 at 2.30MiB/s
# Converted and saved as WAV: output_audio_files\audio_26.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=zX4hfPn-ls4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=34
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=zX4hfPn-ls4&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=34
# [youtube:tab] Downloading just the video zX4hfPn-ls4 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zX4hfPn-ls4
# [youtube] zX4hfPn-ls4: Downloading webpage
# [youtube] zX4hfPn-ls4: Downloading ios player API JSON
# [youtube] zX4hfPn-ls4: Downloading mweb player API JSON
# [youtube] zX4hfPn-ls4: Downloading m3u8 information
# [info] zX4hfPn-ls4: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_27.webm
# [download] 100% of   30.29MiB in 00:00:15 at 1.91MiB/s
# Converted and saved as WAV: output_audio_files\audio_27.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=KnE6NPtjx3s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=35
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=KnE6NPtjx3s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=35
# [youtube:tab] Downloading just the video KnE6NPtjx3s because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KnE6NPtjx3s
# [youtube] KnE6NPtjx3s: Downloading webpage
# [youtube] KnE6NPtjx3s: Downloading ios player API JSON
# [youtube] KnE6NPtjx3s: Downloading mweb player API JSON
# [youtube] KnE6NPtjx3s: Downloading m3u8 information
# [info] KnE6NPtjx3s: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_28.webm
# [download] 100% of   35.52MiB in 00:00:16 at 2.11MiB/s
# Converted and saved as WAV: output_audio_files\audio_28.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=L8Dj1v5QV_s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=36
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=L8Dj1v5QV_s&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=36
# [youtube:tab] Downloading just the video L8Dj1v5QV_s because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L8Dj1v5QV_s
# [youtube] L8Dj1v5QV_s: Downloading webpage
# [youtube] L8Dj1v5QV_s: Downloading ios player API JSON
# [youtube] L8Dj1v5QV_s: Downloading mweb player API JSON
# [youtube] L8Dj1v5QV_s: Downloading m3u8 information
# [info] L8Dj1v5QV_s: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_29.webm
# [download] 100% of   30.06MiB in 00:00:16 at 1.87MiB/s
# Converted and saved as WAV: output_audio_files\audio_29.wav
# Attempting to download audio from: https://www.youtube.com/watch?v=J6FDpdhW0ns&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=37
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=J6FDpdhW0ns&list=PLQpF--VlgguTJg7_4FTGrdvugpMsuXWDQ&index=37
# [youtube:tab] Downloading just the video J6FDpdhW0ns because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J6FDpdhW0ns
# [youtube] J6FDpdhW0ns: Downloading webpage
# [youtube] J6FDpdhW0ns: Downloading ios player API JSON
# [youtube] J6FDpdhW0ns: Downloading mweb player API JSON
# [youtube] J6FDpdhW0ns: Downloading m3u8 information
# [info] J6FDpdhW0ns: Downloading 1 format(s): 251
# [download] Destination: output_audio_files\audio_30.webm
# [download] 100% of   27.23MiB in 00:00:13 at 2.02MiB/s
# Converted and saved as WAV: output_audio_files\audio_30.wav
# Script completed.

# %% [markdown]
# ## Convert Audio to Text (1 to 14)

# %%
import speech_recognition as sr
import logging
from pydub import AudioSegment
import os

# Set up logging
logging.basicConfig(level=logging.INFO)

def convert_to_pcm_mono(wav_file):
    """Convert audio file to mono PCM WAV format."""
    try:
        audio = AudioSegment.from_file(wav_file)
        audio = audio.set_channels(1)  # Convert to mono
        audio = audio.set_frame_rate(16000)  # Set sample rate to 16 kHz
        converted_file = "converted_audio_mono.wav"
        audio.export(converted_file, format="wav", codec="pcm_s16le")  # Ensure PCM format
        logging.info(f"Converted audio saved as: {converted_file}")
        return converted_file
    except Exception as e:
        logging.error(f"Error converting audio file: {e}")
        return None

def split_audio(wav_file, segment_length=60):
    """Split audio into segments of a specified length (in seconds)."""
    audio = AudioSegment.from_file(wav_file)
    segments = []
    for i in range(0, len(audio), segment_length * 1000):  # Convert to milliseconds
        segment = audio[i:i + segment_length * 1000]
        segment_file = f"segment_{i // 1000}.wav"
        segment.export(segment_file, format="wav", codec="pcm_s16le")
        segments.append(segment_file)
        logging.info(f"Exported segment: {segment_file} (Duration: {len(segment) / 1000:.2f} seconds)")
    return segments

def wav_to_text(wav_file):
    """Convert a WAV file to text using Google Speech Recognition."""
    r = sr.Recognizer()
    
    # Convert audio file to mono PCM format
    converted_file = convert_to_pcm_mono(wav_file)
    if converted_file is None:
        return None

    # Split audio into segments if longer than 60 seconds
    segments = split_audio(converted_file, segment_length=60)
    full_transcription = ""

    for segment in segments:
        with sr.AudioFile(segment) as source:
            audio_data = r.record(source)  # Read the entire audio file
            try:
                text = r.recognize_google(audio_data)
                full_transcription += text + " "
                logging.info(f"Transcribed segment: {segment}")
            except sr.UnknownValueError:
                logging.error("Could not understand audio in segment")
            except sr.RequestError as e:
                logging.error(f"Could not request results for {segment}; {e}")
                if "Bad Request" in str(e):
                    logging.error("Bad request. Check audio file and format.")
    
    return full_transcription.strip()

def process_audio_files(audio_files, output_file):
    """Process a list of audio files and write transcription to an output text file."""
    with open(output_file, 'w', encoding='utf-8') as f:
        for wav_file in audio_files:
            if not os.path.isfile(wav_file):
                logging.error(f"File not found: {wav_file}")
                f.write(f"File not found: {wav_file}\n")
            else:
                transcription = wav_to_text(wav_file)
                if transcription:
                    logging.info(f"Transcription for {wav_file} completed.")
                    f.write(f"Transcription for {wav_file}:\n{transcription}\n\n")
                else:
                    logging.error(f"Transcription failed for {wav_file}.")
                    f.write(f"Transcription failed for {wav_file}.\n\n")

if __name__ == "__main__":
    # Example usage
    audio_files = [f'C:\\Users\\HP\\Python\\Assignment & Project\\output_audio_files\\audio_{i}.wav' for i in range(1, 15)]
    output_file = r'C:\Users\HP\Python\Assignment & Project\transcriptions.txt'
    
    process_audio_files(audio_files, output_file)
# Out:
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 21.28 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_1.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 0.90 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_2.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 51.50 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_3.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 55.60 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_4.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2460.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2520.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2580.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2640.wav (Duration: 25.26 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# INFO:root:Transcribed segment: segment_2400.wav
# INFO:root:Transcribed segment: segment_2460.wav
# INFO:root:Transcribed segment: segment_2520.wav
# INFO:root:Transcribed segment: segment_2580.wav
# INFO:root:Transcribed segment: segment_2640.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_5.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 55.34 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_6.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 30.54 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_7.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2460.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2520.wav (Duration: 50.86 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# INFO:root:Transcribed segment: segment_2400.wav
# INFO:root:Transcribed segment: segment_2460.wav
# INFO:root:Transcribed segment: segment_2520.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_8.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 11.20 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_9.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 52.04 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_10.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 53.16 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_11.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 54.53 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_12.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2460.wav (Duration: 55.73 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# INFO:root:Transcribed segment: segment_2400.wav
# INFO:root:Transcribed segment: segment_2460.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_13.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 21.01 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_14.wav completed.

# %% [markdown]
# ## Convert Audio to Text (15 to 30)

# %%
import speech_recognition as sr
import logging
from pydub import AudioSegment
import os

# Set up logging
logging.basicConfig(level=logging.INFO)

def convert_to_pcm_mono(wav_file):
    """Convert audio file to mono PCM WAV format."""
    try:
        audio = AudioSegment.from_file(wav_file)
        audio = audio.set_channels(1)  # Convert to mono
        audio = audio.set_frame_rate(16000)  # Set sample rate to 16 kHz
        converted_file = "converted_audio_mono.wav"
        audio.export(converted_file, format="wav", codec="pcm_s16le")  # Ensure PCM format
        logging.info(f"Converted audio saved as: {converted_file}")
        return converted_file
    except Exception as e:
        logging.error(f"Error converting audio file: {e}")
        return None

def split_audio(wav_file, segment_length=60):
    """Split audio into segments of a specified length (in seconds)."""
    audio = AudioSegment.from_file(wav_file)
    segments = []
    for i in range(0, len(audio), segment_length * 1000):  # Convert to milliseconds
        segment = audio[i:i + segment_length * 1000]
        segment_file = f"segment_{i // 1000}.wav"
        segment.export(segment_file, format="wav", codec="pcm_s16le")
        segments.append(segment_file)
        logging.info(f"Exported segment: {segment_file} (Duration: {len(segment) / 1000:.2f} seconds)")
    return segments

def wav_to_text(wav_file):
    """Convert a WAV file to text using Google Speech Recognition."""
    r = sr.Recognizer()
    
    # Convert audio file to mono PCM format
    converted_file = convert_to_pcm_mono(wav_file)
    if converted_file is None:
        return None

    # Split audio into segments if longer than 60 seconds
    segments = split_audio(converted_file, segment_length=60)
    full_transcription = ""

    for segment in segments:
        with sr.AudioFile(segment) as source:
            audio_data = r.record(source)  # Read the entire audio file
            try:
                text = r.recognize_google(audio_data)
                full_transcription += text + " "
                logging.info(f"Transcribed segment: {segment}")
            except sr.UnknownValueError:
                logging.error("Could not understand audio in segment")
            except sr.RequestError as e:
                logging.error(f"Could not request results for {segment}; {e}")
                if "Bad Request" in str(e):
                    logging.error("Bad request. Check audio file and format.")
    
    return full_transcription.strip()

def process_audio_files(audio_files, output_file):
    """Process a list of audio files and write transcription to an output text file."""
    with open(output_file, 'w', encoding='utf-8') as f:
        for wav_file in audio_files:
            if not os.path.isfile(wav_file):
                logging.error(f"File not found: {wav_file}")
                f.write(f"File not found: {wav_file}\n")
            else:
                transcription = wav_to_text(wav_file)
                if transcription:
                    logging.info(f"Transcription for {wav_file} completed.")
                    f.write(f"Transcription for {wav_file}:\n{transcription}\n\n")
                else:
                    logging.error(f"Transcription failed for {wav_file}.")
                    f.write(f"Transcription failed for {wav_file}.\n\n")

if __name__ == "__main__":
    # Example usage
    audio_files = [f'C:\\Users\\HP\\Python\\Assignment & Project\\output_audio_files\\audio_{i}.wav' for i in range(15, 31)]
    output_file = r'C:\Users\HP\Python\Assignment & Project\transcriptions1.txt'
    
    process_audio_files(audio_files, output_file)
# Out:
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 15.05 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_15.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 5.76 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_16.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 39.69 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_17.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 18.82 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_18.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 36.48 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_19.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 35.82 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_20.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 57.60 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_21.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 15.53 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_22.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 2.22 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_23.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 32.84 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_24.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 47.40 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_25.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# ...
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 15.85 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_27.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2220.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2280.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2340.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2400.wav (Duration: 49.92 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcribed segment: segment_2220.wav
# INFO:root:Transcribed segment: segment_2280.wav
# INFO:root:Transcribed segment: segment_2340.wav
# INFO:root:Transcribed segment: segment_2400.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_28.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2160.wav (Duration: 42.49 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# INFO:root:Transcribed segment: segment_2100.wav
# INFO:root:Transcribed segment: segment_2160.wav
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_29.wav completed.
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 13.13 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_30.wav completed.

# %% [markdown]
# ## Final Transcriptions File

# %%
# Specify the input file names with raw strings
file1 = r'C:\Users\HP\Python\Assignment & Project\transcriptions.txt'
file2 = r'C:\Users\HP\Python\Assignment & Project\transcriptions1.txt'

# Specify the output file name
output_file = r'C:\Users\HP\Python\Assignment & Project\Interview_Transcription.txt'

# Open the output file in write mode
with open(output_file, 'w') as outfile:
    # Read and write the contents of the first file
    with open(file1, 'r') as f1:
        outfile.write(f1.read())
        outfile.write("\n")  # Add a newline to separate content from both files

    # Read and write the contents of the second file
    with open(file2, 'r') as f2:
        outfile.write(f2.read())

print(f"Files {file1} and {file2} have been merged into {output_file}")
# Out:
# Files C:\Users\HP\Python\Assignment & Project\transcriptions.txt and C:\Users\HP\Python\Assignment & Project\transcriptions1.txt have been merged into C:\Users\HP\Python\Assignment & Project\Interview_Transcription.txt

# %% [markdown]
# ## Split Transcriptions Files

# %%
import re
import os

# Input and output file paths
input_file = r'C:\Users\HP\Python\Assignment & Project\Interview_Transcription.txt'
output_folder = r'C:\Users\HP\Python\Assignment & Project\Interview_Split_Transcriptions_Files'

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Open the main transcription file
with open(input_file, 'r', encoding='utf-8') as file:
    content = file.read()

# Split the content based on each audio file's transcription using a regex pattern
# Assuming each transcription starts with "Transcription for {filepath}"
transcriptions = re.split(r'(Transcription for .+?\.wav:)', content)

# Loop through the split transcriptions and save each as a separate file
for i in range(1, len(transcriptions), 2):
    # File name and content
    file_name = transcriptions[i].strip().replace('Transcription for ', '').replace(':', '').replace('\\', '_').replace('/', '_')
    transcription_content = transcriptions[i] + transcriptions[i + 1]

    # Output path
    output_path = os.path.join(output_folder, f"{file_name}.txt")

    # Write each transcription to a new file
    with open(output_path, 'w', encoding='utf-8') as output_file:
        output_file.write(transcription_content)

print(f"Transcriptions have been saved to the '{output_folder}' folder.")
# Out:
# Transcriptions have been saved to the 'C:\Users\HP\Python\Assignment & Project\Interview_Split_Transcriptions_Files' folder.

# %%
import nltk
nltk.download('brown')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import re

def read_interview_file(file_path):
    """Read the interview text file and return its content."""
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    return content

def parse_questions_answers(content):
    """Parse the content to segregate questions and answers."""
    # Split the content based on the question and answer format
    qa_pairs = re.findall(r'(Q:.*?)(?=Q:|$)', content, re.DOTALL)
    parsed_qa = []

    for qa in qa_pairs:
        question, answer = qa.split('A:', 1) if 'A:' in qa else (qa, "")
        parsed_qa.append({
            'question': question.strip(),
            'answer': answer.strip(),
            'tag': '',  # Placeholder for tagging
            'category': ''  # Placeholder for categorization
        })

    return parsed_qa

def categorize_answer(answer):
    """Categorize the answer as 'good' or 'bad' based on predefined criteria."""
    if len(answer) < 50:
        return 'bad'  # Example criterion: too short
    elif any(keyword in answer.lower() for keyword in ['excellent', 'great', 'good']):
        return 'good'
    else:
        return 'bad'

def tag_and_categorize_qa(parsed_qa):
    """Tag and categorize each question-answer pair."""
    for qa in parsed_qa:
        # Example tagging logic (you can expand this)
        qa['tag'] = "UPSC_Interview"

        # Categorize the answer
        qa['category'] = categorize_answer(qa['answer'])

def write_output_file(output_path, parsed_qa):
    """Write the tagged and categorized QA pairs to an output file."""
    with open(output_path, 'w', encoding='utf-8') as file:
        for qa in parsed_qa:
            file.write(f"Question: {qa['question']}\n")
            file.write(f"Answer: {qa['answer']}\n")
            file.write(f"Tag: {qa['tag']}\n")
            file.write(f"Category: {qa['category']}\n")
            file.write("\n---\n\n")

def main():
    input_file_path = 'C:\\Users\\HP\\Python\\split_transcriptions\\C_Users_HP_Python_Assignment & Project_output_audio_files_audio_1.wav.txt'  # Path to the input file
    output_file_path = 'tagged_upsc_interview.txt'  # Path to the output file

    # Step 1: Read the interview file
    content = read_interview_file(input_file_path)

    # Step 2: Parse questions and answers
    parsed_qa = parse_questions_answers(content)

    # Step 3: Tag and categorize
    tag_and_categorize_qa(parsed_qa)

    # Step 4: Write output to a new file
    write_output_file(output_file_path, parsed_qa)

if __name__ == "__main__":
    main()

# %%
pip install SpeechRecognition pydub textblob
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\hp\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: pydub in c:\users\hp\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hp\anaconda3\lib\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from SpeechRecognition) (4.7.1)
# Requirement already satisfied: nltk>=3.8 in c:\users\hp\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import logging
from pydub import AudioSegment
import os
from textblob import TextBlob

# Set up logging
logging.basicConfig(level=logging.INFO)

def convert_to_pcm_mono(wav_file):
    """Convert audio file to mono PCM WAV format."""
    try:
        audio = AudioSegment.from_file(wav_file)
        audio = audio.set_channels(1)  # Convert to mono
        audio = audio.set_frame_rate(16000)  # Set sample rate to 16 kHz
        converted_file = "converted_audio_mono.wav"
        audio.export(converted_file, format="wav", codec="pcm_s16le")  # Ensure PCM format
        logging.info(f"Converted audio saved as: {converted_file}")
        return converted_file
    except Exception as e:
        logging.error(f"Error converting audio file: {e}")
        return None

def split_audio(wav_file, segment_length=60):
    """Split audio into segments of a specified length (in seconds)."""
    audio = AudioSegment.from_file(wav_file)
    segments = []
    for i in range(0, len(audio), segment_length * 1000):  # Convert to milliseconds
        segment = audio[i:i + segment_length * 1000]
        segment_file = f"segment_{i // 1000}.wav"
        segment.export(segment_file, format="wav", codec="pcm_s16le")
        segments.append(segment_file)
        logging.info(f"Exported segment: {segment_file} (Duration: {len(segment) / 1000:.2f} seconds)")
    return segments

def wav_to_text(wav_file):
    """Convert a WAV file to text using Google Speech Recognition."""
    r = sr.Recognizer()
    
    # Convert audio file to mono PCM format
    converted_file = convert_to_pcm_mono(wav_file)
    if converted_file is None:
        return None

    # Split audio into segments if longer than 60 seconds
    segments = split_audio(converted_file, segment_length=60)
    full_transcription = ""

    for segment in segments:
        with sr.AudioFile(segment) as source:
            audio_data = r.record(source)  # Read the entire audio file
            try:
                text = r.recognize_google(audio_data)
                full_transcription += text + " "
                logging.info(f"Transcribed segment: {segment}")
            except sr.UnknownValueError:
                logging.error("Could not understand audio in segment")
            except sr.RequestError as e:
                logging.error(f"Could not request results for {segment}; {e}")
    
    return full_transcription.strip()

def tag_answer_quality(answer):
    """Tag answers based on advanced criteria for UPSC interview context."""
    tags = []

    # Content Relevance and Depth
    if len(answer.split()) > 50:
        tags.append("Content: Excellent")
    elif len(answer.split()) > 20:
        tags.append("Content: Good")
    else:
        tags.append("Content: Weak")

    # Confidence Level
    if any(phrase in answer.lower() for phrase in ["absolutely", "i firmly believe", "i am certain"]):
        tags.append("Confidence: High")
    elif any(phrase in answer.lower() for phrase in ["i think", "maybe", "perhaps", "i am not sure"]):
        tags.append("Confidence: Low")
    else:
        tags.append("Confidence: Moderate")

    # Structured Answer
    if any(phrase in answer.lower() for phrase in ["first", "second", "finally", "in conclusion", "to summarize"]):
        tags.append("Structure: Well-Structured")
    else:
        tags.append("Structure: Unstructured")

    # Emotional Intelligence
    if any(phrase in answer.lower() for phrase in ["i understand", "i empathize", "it is important to consider"]):
        tags.append("Emotional Intelligence: High")
    else:
        tags.append("Emotional Intelligence: Neutral/Low")

    # Tone Analysis using TextBlob
    analysis = TextBlob(answer)
    polarity = analysis.sentiment.polarity
    if polarity > 0.2:
        tags.append("Tone: Positive")
    elif polarity < -0.2:
        tags.append("Tone: Negative")
    else:
        tags.append("Tone: Neutral")

    # Conciseness
    if len(answer.split()) < 30:
        tags.append("Conciseness: Concise")
    else:
        tags.append("Conciseness: Verbose")

    return ", ".join(tags)

def process_audio_files(audio_files, output_file):
    """Process a list of audio files, transcribe them, and categorize the transcriptions."""
    with open(output_file, 'w', encoding='utf-8') as f:
        for wav_file in audio_files:
            if not os.path.isfile(wav_file):
                logging.error(f"File not found: {wav_file}")
                f.write(f"File not found: {wav_file}\n")
            else:
                transcription = wav_to_text(wav_file)
                if transcription:
                    logging.info(f"Transcription for {wav_file} completed.")
                    tags = tag_answer_quality(transcription)
                    f.write(f"Transcription for {wav_file}:\n{transcription}\n")
                    f.write(f"Tags: {tags}\n")
                    f.write("-" * 50 + "\n\n")
                else:
                    logging.error(f"Transcription failed for {wav_file}.")
                    f.write(f"Transcription failed for {wav_file}.\n\n")

if __name__ == "__main__":
    # Example usage
    # List of audio files - Make sure to provide them as a list, even if it's just one file
    audio_files = [
        r'C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_1.wav'
    ]
    output_file = r'C:\Users\HP\Python\Assignment & Project\transcriptions1_tagged.txt'
    
    process_audio_files(audio_files, output_file)
# Out:
# INFO:root:Converted audio saved as: converted_audio_mono.wav
# INFO:root:Exported segment: segment_0.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_60.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_120.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_180.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_240.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_300.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_360.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_420.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_480.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_540.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_600.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_660.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_720.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_780.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_840.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_900.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_960.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1020.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1080.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1140.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1200.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1260.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1320.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1380.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1440.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1500.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1560.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1620.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1680.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1740.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1800.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1860.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1920.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_1980.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2040.wav (Duration: 60.00 seconds)
# INFO:root:Exported segment: segment_2100.wav (Duration: 21.28 seconds)
# INFO:root:Transcribed segment: segment_0.wav
# INFO:root:Transcribed segment: segment_60.wav
# INFO:root:Transcribed segment: segment_120.wav
# INFO:root:Transcribed segment: segment_180.wav
# INFO:root:Transcribed segment: segment_240.wav
# INFO:root:Transcribed segment: segment_300.wav
# INFO:root:Transcribed segment: segment_360.wav
# INFO:root:Transcribed segment: segment_420.wav
# INFO:root:Transcribed segment: segment_480.wav
# INFO:root:Transcribed segment: segment_540.wav
# INFO:root:Transcribed segment: segment_600.wav
# INFO:root:Transcribed segment: segment_660.wav
# INFO:root:Transcribed segment: segment_720.wav
# INFO:root:Transcribed segment: segment_780.wav
# INFO:root:Transcribed segment: segment_840.wav
# INFO:root:Transcribed segment: segment_900.wav
# INFO:root:Transcribed segment: segment_960.wav
# INFO:root:Transcribed segment: segment_1020.wav
# INFO:root:Transcribed segment: segment_1080.wav
# INFO:root:Transcribed segment: segment_1140.wav
# INFO:root:Transcribed segment: segment_1200.wav
# INFO:root:Transcribed segment: segment_1260.wav
# INFO:root:Transcribed segment: segment_1320.wav
# INFO:root:Transcribed segment: segment_1380.wav
# INFO:root:Transcribed segment: segment_1440.wav
# INFO:root:Transcribed segment: segment_1500.wav
# INFO:root:Transcribed segment: segment_1560.wav
# INFO:root:Transcribed segment: segment_1620.wav
# INFO:root:Transcribed segment: segment_1680.wav
# INFO:root:Transcribed segment: segment_1740.wav
# INFO:root:Transcribed segment: segment_1800.wav
# INFO:root:Transcribed segment: segment_1860.wav
# INFO:root:Transcribed segment: segment_1920.wav
# INFO:root:Transcribed segment: segment_1980.wav
# INFO:root:Transcribed segment: segment_2040.wav
# ERROR:root:Could not understand audio in segment
# INFO:root:Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_1.wav completed.

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\hp\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
from textblob import TextBlob

# File paths
input_file = r'C:\Users\HP\Python\Assignment & Project\transcriptions1_tagged.txt'
output_file = r'C:\Users\HP\Python\Assignment & Project\categorized_interview_transcriptions.txt'

def tag_answer_quality(answer):
    """Tag answers based on advanced criteria for UPSC interview context."""
    tags = []

    # Content Relevance and Depth
    if len(answer.split()) > 50:
        tags.append("Content: Excellent")
    elif len(answer.split()) > 20:
        tags.append("Content: Good")
    else:
        tags.append("Content: Weak")

    # Confidence Level
    if any(phrase in answer.lower() for phrase in ["absolutely", "i firmly believe", "i am certain"]):
        tags.append("Confidence: High")
    elif any(phrase in answer.lower() for phrase in ["i think", "maybe", "perhaps", "i am not sure"]):
        tags.append("Confidence: Low")
    else:
        tags.append("Confidence: Moderate")

    # Structured Answer
    if any(phrase in answer.lower() for phrase in ["first", "second", "finally", "in conclusion", "to summarize"]):
        tags.append("Structure: Well-Structured")
    else:
        tags.append("Structure: Unstructured")

    # Emotional Intelligence
    if any(phrase in answer.lower() for phrase in ["i understand", "i empathize", "it is important to consider"]):
        tags.append("Emotional Intelligence: High")
    else:
        tags.append("Emotional Intelligence: Neutral/Low")

    # Tone Analysis using TextBlob
    analysis = TextBlob(answer)
    polarity = analysis.sentiment.polarity
    if polarity > 0.2:
        tags.append("Tone: Positive")
    elif polarity < -0.2:
        tags.append("Tone: Negative")
    else:
        tags.append("Tone: Neutral")

    # Conciseness
    if len(answer.split()) < 30:
        tags.append("Conciseness: Concise")
    else:
        tags.append("Conciseness: Verbose")

    return tags

def categorize_answer(tags):
    """Categorize the answer as Good or Bad based on tags."""
    if "Content: Weak" in tags or "Confidence: Low" in tags or "Tone: Negative" in tags:
        return "Bad"
    else:
        return "Good"

def process_transcription_file(input_file, output_file):
    """Process the transcription file to segregate, tag, and categorize answers."""
    try:
        # Read content from the input file
        with open(input_file, 'r', encoding='utf-8') as infile:
            content = infile.read()

        # Debug: Check if the content was read correctly
        if not content:
            print("The input file is empty or could not be read correctly.")
            return
        else:
            print("Content of input file successfully read.")
            print("------ Content Preview ------")
            print(content[:500])  # Print first 500 characters for inspection
            print("----------------------------")

        # Regular expressions to match questions and answers
        qa_pairs = re.split(r'\n-{20,}\n', content)  # Split by the separator lines with 20 or more dashes

        # Debug: Check the number of QA pairs found
        print(f"Number of QA pairs found: {len(qa_pairs)}")

        if len(qa_pairs) == 0:
            print("No question-answer pairs found. Please check the input format.")
            return

        with open(output_file, 'w', encoding='utf-8') as outfile:
            outfile.write("--- Categorized Interview Transcriptions ---\n\n")

            for idx, qa in enumerate(qa_pairs):
                qa = qa.strip()
                if not qa:
                    continue

                # Debug: Print the current question-answer pair being processed
                print(f"Processing QA pair {idx + 1}:")
                print(qa)
                print("-" * 50)

                # Extract question and answer using regex
                question_match = re.search(r'Question:\s*(.+)', qa, re.IGNORECASE)
                answer_match = re.search(r'Answer:\s*(.+)', qa, re.IGNORECASE)

                if question_match and answer_match:
                    question = question_match.group(1).strip()
                    answer = answer_match.group(1).strip()

                    # Debug: Ensure the question and answer are properly extracted
                    print(f"Extracted Question: {question}")
                    print(f"Extracted Answer: {answer}")

                    # Get advanced tags for the answer
                    tags = tag_answer_quality(answer)

                    # Categorize the answer
                    category = categorize_answer(tags)

                    # Write to output file
                    outfile.write(f"Question: {question}\n")
                    outfile.write(f"Answer: {answer}\n")
                    outfile.write(f"Tags: {', '.join(tags)}\n")
                    outfile.write(f"Category: {category}\n")
                    outfile.write("-" * 50 + "\n\n")

                    # Debugging output
                    print(f"Tags: {tags}")
                    print(f"Category: {category}")
                    print("-" * 50)
                else:
                    # Debug: Print if no valid Q&A found
                    print("No valid question and/or answer found in this segment. Skipping...")
                    print("-" * 50)

        print(f"Categorized transcription saved to '{output_file}'.")

    except FileNotFoundError:
        print(f"Error: The file '{input_file}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    process_transcription_file(input_file, output_file)
# Out:
# Content of input file successfully read.
# ------ Content Preview ------
# Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_1.wav:
# tell me why do you want to join the civil services for working the Qualcomm getting a very handsome salary why do you want to compromise on less salary in the Civil Services why do we have largest countries so tell me something about the city and also its social fabric can you tell us whether some relationships and adverse weather phenomena when was this Island territory needed to Sri Lanka yes coming good
# ----------------------------
# Number of QA pairs found: 2
# Processing QA pair 1:
# Transcription for C:\Users\HP\Python\Assignment & Project\output_audio_files\audio_1.wav:
# tell me why do you want to join the civil services for working the Qualcomm getting a very handsome salary why do you want to compromise on less salary in the Civil Services why do we have largest countries so tell me something about the city and also its social fabric can you tell us whether some relationships and adverse weather phenomena when was this Island territory needed to Sri Lanka yes coming good morning good morning please give a brief introduction about yourself I am from Srikakulam district of Andhra Pradesh I am from village background and my parents are into agriculture I have done my graduation from NIT Trichy in electronics and communication engineering I graduated in 2019 after that I worked as a chip design engineer in Qualcomm for more than 2 years after that I have written and started preparing for civil services this is my second attempt and first interviews tell me why do you want to join the civil services working the Qualcomm getting a very handsome salary what do you want to compromise on less salary in passionate about civil services because civil services as a career will give me diverse opportunities and growth in this sector and I am also very much satisfied if I can get second get to work close to the people if you can problems I will be more satisfied explain to us why I have chosen is your first preference why not any other service as a career gives me diverse opportunities at the start of the career I will get to work close to the people at the Grass root level and as I go up the ladder I will get the I will get to use this experience and in policy making this will help me do you think that is only IAS who can solve all problems of the country is one of the civil services who play active part in the administration and policy making other than this all the other services also have their own utility and all the services together will contribute to the social economic growth of the countries electronics and all so why it is semiconductor issue of discussion in the country semiconductors what is the role in particular every sector that we operate today rate from agriculture towards defence industry we have a lot of dependence on semiconductors in the demand is going to increase in the future tense that is why government also prioritise this sector and came up with the national semiconductor mission so as to establish N2 and system in the country right from designing to fabrication we have to establish the whole supply chain in the market so that are import dependency will reduce and it will add to our security as well what are the issues in semiconductor in the country in the semiconductor change today we are very good in the design front we have very good human resources but we do not have a fabrication ecosystem in the country because fabrication requires a lot of capital establishing a single friend request billions of dollars in investment under the same time we are also depending on imports for lot of raw materials right from Silicon Wafers we are depending China forever imports and also this is highly Technology intensive and it requires continuous upgradation particularly the fabrication plants so these challenges are coming in the way of establishing a robust system in the country but we are releasing the importance and we are moving forward to partner with the private sector to establish the system in the country is grappling with regard to invest to find out the solution rapidly progressing towards the CV ecosystem because of the commitments we have towards meeting of global targets but Rapid adaptation and challenges today particularly the battery systems are not very efficient and we cannot go long distances using the present battery setup and also we have certain bottlenecks in the infrastructure as well we do not have a robust charging infrastructure across the country so that it will limit the adoption and also the receipt and safety concerns as well associated with these batteries  ...
# Tags: Content: Excellent, Confidence: Low, Structure: Well-Structured, Emotional Intelligence: Neutral/Low, Tone: Neutral, Conciseness: Verbose
# --------------------------------------------------
# No valid question and/or answer found in this segment. Skipping...
# --------------------------------------------------
# Categorized transcription saved to 'C:\Users\HP\Python\Assignment & Project\categorized_interview_transcriptions.txt'.
